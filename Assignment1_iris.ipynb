# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # reading the dataset

# %%
iris=pd.read_excel(r'C:\Users\Anjali\iris.xls')

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # columns in dataset

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # mean of each column

# %%
iris.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # checking for null values

# %%
iris.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # visualization

# %%
sns.pairplot(iris)

# %%
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='SW',y='SL',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='SL'>

# %%
sns.boxplot(x='PW',y='PL',data=iris)
# Out:
# <AxesSubplot:xlabel='PW', ylabel='PL'>

# %%
sns.stripplot(x='SW',y='SL',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='SL'>

# %%
sns.swarmplot(x='SW',y='SL',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='SL'>

# %%
sns.stripplot(x='SW',y='SL',data=iris)
sns.swarmplot(x='SW',y='SL',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='SL'>

# %%
sns.stripplot(x='PW',y='PL',data=iris)
sns.swarmplot(x='PW',y='PL',data=iris)
# Out:
# <AxesSubplot:xlabel='PW', ylabel='PL'>
